# %% [markdown]
# <a href="https://colab.research.google.com/github/KamalAsh0ur/CognRoise-Infotech/blob/main/salaries1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
df = df.drop(['Unnamed: 0', 'work_year'], axis=1)

# %% [markdown]
# # Distribution of salaries

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['employment_type'].value_counts()
    for x_label, grp in _df_44.groupby('experience_level')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('experience_level')
_ = plt.ylabel('employment_type')

# %%
_df_3['salary_in_usd'].plot(kind='hist', bins=20, title='salary_in_usd')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
pd.read_csv('/content/sample_data/ds_salaries (1).csv', encoding='latin1' ).head()
df = pd.read_csv('/content/sample_data/ds_salaries (1).csv', encoding='latin1' )
df2 = df[['job_title', 'salary_in_usd']]
df2.groupby('job_title').mean(['salary_in_usd'])
df2.head()
# Out:
#                     job_title  salary_in_usd
# 0              Data Scientist          79833
# 1  Machine Learning Scientist         260000
# 2           Big Data Engineer         109024
# 3        Product Data Analyst          20000
# 4   Machine Learning Engineer         150000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_60['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_61['salary_in_usd'].plot(kind='hist', bins=20, title='salary_in_usd')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df2.groupby('job_title').mean(['salary_in_usd']).reset_index()

alt.Chart(source).mark_rect().encode(
    y=alt.Y('job_title:N', sort='-x'),
    color='salary_in_usd:Q',
    x=alt.X('sum(salary_in_usd):Q', stack="normalize")
)
# Out:
# /usr/local/lib/python3.10/dist-packages/altair/utils/core.py:384: FutureWarning:
#
# the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# alt.Chart(...)

# %%
pd.read_csv('/content/sample_data/ds_salaries (1).csv', encoding='latin1' ).head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df3 = df[df['job_title'].isin(['Data Analyst', 'Data Scientist', 'Machine Learning Engineer'])]
df3.groupby('experience_level').mean(['salary_in_usd'])
# Out:
#                   Unnamed: 0    work_year         salary  salary_in_usd  \
# experience_level
# EN                199.534884  2020.906977  202283.813953   61576.162791
# EX                326.500000  2022.000000  120000.000000  120000.000000
# MI                285.772277  2021.306931  590298.475248   78170.534653
# SE                399.051852  2021.785185  182869.733333  133322.770370
#
#                   remote_ratio
# experience_level
# EN                   65.116279
# EX                  100.000000
# MI                   59.900990
# SE                   75.185185

# %%
df3.groupby('experience_level').mean(['salary_in_usd']).reset_index()
fig = px.pie(df_pie, values='salary_in_usd', names='experience_level', title='Average Salary by Experience Level')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
