# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Unemployment in India.csv', encoding='latin-1')
df2 = pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv', encoding='latin-1')

# %%
appended_df = pd.concat([df, df2], ignore_index=True)
data = appended_df

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Area'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x=' Estimated Employed', y='Area', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-31-209d4f485221>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
from matplotlib import pyplot as plt
df[' Estimated Unemployment Rate (%)'].plot(kind='hist', bins=20, title=' Estimated Unemployment Rate (%)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df[' Estimated Labour Participation Rate (%)'].plot(kind='line', figsize=(8, 4), title=' Estimated Labour Participation Rate (%)') # Changed _df_35 to df
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_24.plot(kind='scatter', x=' Estimated Employed', y=' Estimated Labour Participation Rate (%)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_27[' Estimated Labour Participation Rate (%)'].plot(kind='line', figsize=(12, 4), title=' Estimated Labour Participation Rate (%)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_18[' Estimated Employed'].plot(kind='line', figsize=(12, 4), title=' Estimated Employed')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df2.groupby('Region.1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df2[' Estimated Labour Participation Rate (%)'].plot(kind='hist', bins=20, title=' Estimated Labour Participation Rate (%)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df2[' Estimated Unemployment Rate (%)'].plot(kind='hist', bins=20, title=' Estimated Unemployment Rate (%)')
plt.gca().spines[['top', 'right',]].set_visible(False)
